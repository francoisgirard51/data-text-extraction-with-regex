# %% [markdown]
# # Part 1: Working with Regex

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib
import re

# %% [markdown]
# ## Intro to Regex

# %%
pattern = r"\d{10}"
text_to_search = "Hello my name is sebastien, you can call me on 0664533519. See you!"
re.findall(pattern, text_to_search)
# Out:
# ['0664533519']

# %%
date_pattern = r"\d{2}-\d{2}-\d{4}"
text_to_search = "Receipt Number 103402 ||| 15-02-2017"
re.findall(date_pattern, text_to_search)
# Out:
# ['15-02-2017']

# %%
zip_code_pattern = r"\d{5}"
text_to_search = "I moved to Paris 75011, it's closer to my workplace."
re.findall(zip_code_pattern, text_to_search)
# Out:
# ['75011']

# %%
quantity_pattern = r"Quantity +\d+"
amount_pattern = r"Total Amount +\d+\.\d{2} €"

# %% [markdown]
# ## Groups

# %%
# TEST THIS IN YOUR NOTEBOOK
pattern = r"Receipt Number (\d+)"
text_to_search = "Receipt Number 103402 ||| 15-02-2017"
re.findall(pattern, text_to_search)
# Out:
# ['103402']

# %%
quantity_group_pattern = r"Quantity +(\d+)"
amount_group_pattern = r"Total Amount +(\d+\.\d{2}) €"

# %%
from nbresult import ChallengeResult

result = ChallengeResult('patterns',
    zipcode_re=zip_code_pattern,
    date_re=date_pattern,
    quantity_re=quantity_pattern,
                         
    amount_re=amount_pattern,
    quantity_grp_re=quantity_group_pattern,
    amount_grp_re=amount_group_pattern
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /Users/francoisgirard/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/francoisgirard/code/francoisgirard51/02-Data-Toolkit/02-Data-Sourcing/data-text-extraction-with-regex/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 6 items
#
# test_patterns.py::TestPatterns::test_amount_group_pattern PASSED         [ 16%]
# test_patterns.py::TestPatterns::test_amount_pattern PASSED               [ 33%]
# test_patterns.py::TestPatterns::test_date_pattern PASSED                 [ 50%]
# test_patterns.py::TestPatterns::test_quantity_group_pattern PASSED       [ 66%]
# test_patterns.py::TestPatterns::test_quantity_pattern PASSED             [ 83%]
# test_patterns.py::TestPatterns::test_zip_code_pattern PASSED             [100%]
#
# ============================== 6 passed in 0.04s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/patterns.pickle
#
# git commit -m 'Completed patterns step'
#
# git push origin master

# %% [markdown]
# # Part 2: From a text file to a DataFrame

# %%
filepath = "data/receipts.txt"
with open(filepath, encoding="utf-8") as f:
    receipts_str = f.read()
print(receipts_str[:500])
# Out:
# Receipt Number 102790 ||| 02-01-2017
# ------------------------------------
#
# Quantity                         163
# Total Amount               3097.00 €
#
# ====================================
# ************************************
#
#
# Receipt Number 102862 ||| 05-01-2017
# ------------------------------------
#
# Quantity                         110
# Total Amount                935.00 €
#
# ====================================
# ************************************
#
#
# Receipt Number 103086 ||| 23-01-2017
# -----

# %%
receipts_list = receipts_str.split("====================================")
len(receipts_list)
# Out:
# 100

# %%
receipts_dict = {
    "date": [],
    "quantity": [],
    "amount": []
}

# %%
for receipt in receipts_list:
    print(receipt)
# Out:
# Receipt Number 102790 ||| 02-01-2017
# ------------------------------------
#
# Quantity                         163
# Total Amount               3097.00 €
#
#
#
# ************************************
#
#
# Receipt Number 102862 ||| 05-01-2017
# ------------------------------------
#
# Quantity                         110
# Total Amount                935.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103086 ||| 23-01-2017
# ------------------------------------
#
# Quantity                         156
# Total Amount               2808.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103193 ||| 31-01-2017
# ------------------------------------
#
# Quantity                         182
# Total Amount               4368.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103270 ||| 06-02-2017
# ------------------------------------
#
# Quantity                          97
# Total Amount               1988.50 €
#
#
#
# ************************************
#
#
# Receipt Number 103402 ||| 15-02-2017
# ------------------------------------
#
# Quantity                         163
# Total Amount               3586.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103419 ||| 16-02-2017
# ------------------------------------
#
# Quantity                         223
# Total Amount               5017.50 €
#
#
#
# ************************************
#
#
# Receipt Number 103450 ||| 17-02-2017
# ------------------------------------
#
# Quantity                         104
# Total Amount               2756.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103486 ||| 21-02-2017
# ------------------------------------
#
# Quantity                         153
# Total Amount               3060.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103560 ||| 27-02-2017
# ------------------------------------
#
# Quantity                         158
# Total Amount               2686.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103587 ||| 28-02-2017
# ------------------------------------
#
# Quantity                         152
# Total Amount               2584.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103597 ||| 01-03-2017
# ------------------------------------
#
# Quantity                         105
# Total Amount               2835.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103697 ||| 08-03-2017
# ------------------------------------
#
# Quantity                         134
# Total Amount               2613.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103703 ||| 09-03-2017
# ------------------------------------
#
# Quantity                         176
# Total Amount               3344.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103823 ||| 17-03-2017
# ------------------------------------
#
# Quantity                         219
# Total Amount               2847.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103856 ||| 21-03-2017
# ------------------------------------
#
# Quantity                         179
# Total Amount               4475.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103865 ||| 21-03-2017
# ------------------------------------
#
# Quantity                         166
# Total Amount               1660.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103885 ||| 22-03-2017
# ------------------------------------
#
# Quantity                         117
# Total Amount               2164.50 €
#
#
#
# ************************************
#
#
# Receipt Number 103888 ||| 22-03-2017
# ------------------------------------
#
# Quantity                          94
# Total Amount               2115.00 €
#
#
#
# ************************************
#
#
# Receipt Number 103939 ||| 27-03-2017
# ------------------------------------
#
# Quantity                         150
# Total Amount               3375.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104013 ||| 31-03-2017
# ------------------------------------
#
# Quantity                         145
# Total Amount               1595.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104114 ||| 07-04-2017
# ------------------------------------
#
# Quantity                         230
# Total Amount               4600.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104146 ||| 11-04-2017
# ------------------------------------
#
# Quantity                         194
# Total Amount               4753.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104213 ||| 14-04-2017
# ------------------------------------
#
# Quantity                         103
# Total Amount               1390.50 €
#
#
#
# ************************************
#
#
# Receipt Number 104215 ||| 17-04-2017
# ------------------------------------
#
# Quantity                         174
# Total Amount               4611.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104249 ||| 18-04-2017
# ------------------------------------
#
# Quantity                         159
# Total Amount               3021.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104264 ||| 19-04-2017
# ------------------------------------
#
# Quantity                         159
# Total Amount               3577.50 €
#
#
#
# ************************************
#
#
# Receipt Number 104277 ||| 20-04-2017
# ------------------------------------
#
# Quantity                          61
# Total Amount               1342.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104313 ||| 24-04-2017
# ------------------------------------
#
# Quantity                         191
# Total Amount               6016.50 €
#
#
#
# ************************************
#
#
# Receipt Number 104435 ||| 02-05-2017
# ------------------------------------
#
# Quantity                          47
# Total Amount               1269.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104492 ||| 05-05-2017
# ------------------------------------
#
# Quantity                         121
# Total Amount               3085.50 €
#
#
#
# ************************************
#
#
# Receipt Number 104583 ||| 12-05-2017
# ------------------------------------
#
# Quantity                          97
# Total Amount               1891.50 €
#
#
#
# ************************************
#
#
# Receipt Number 104602 ||| 15-05-2017
# ------------------------------------
#
# Quantity                         166
# Total Amount               3569.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104606 ||| 15-05-2017
# ------------------------------------
#
# Quantity                         154
# Total Amount               3850.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104645 ||| 17-05-2017
# ------------------------------------
#
# Quantity                         184
# Total Amount               3312.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104666 ||| 18-05-2017
# ------------------------------------
#
# Quantity                         231
# Total Amount               4735.50 €
#
#
#
# ************************************
#
#
# Receipt Number 104686 ||| 19-05-2017
# ------------------------------------
#
# Quantity                         155
# Total Amount               2945.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104690 ||| 22-05-2017
# ------------------------------------
#
# Quantity                         196
# Total Amount               4116.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104736 ||| 24-05-2017
# ------------------------------------
#
# Quantity                         165
# Total Amount               2310.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104811 ||| 30-05-2017
# ------------------------------------
#
# Quantity                         111
# Total Amount               1998.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104879 ||| 02-06-2017
# ------------------------------------
#
# Quantity                         151
# Total Amount               4379.00 €
#
#
#
# ************************************
#
#
# Receipt Number 104982 ||| 12-06-2017
# ------------------------------------
#
# Quantity                         173
# Total Amount               3373.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105031 ||| 14-06-2017
# ------------------------------------
#
# Quantity                         202
# Total Amount               4444.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105045 ||| 15-06-2017
# ------------------------------------
#
# Quantity                         173
# Total Amount               4584.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105051 ||| 16-06-2017
# ------------------------------------
#
# Quantity                         207
# Total Amount               4036.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105082 ||| 19-06-2017
# ------------------------------------
#
# Quantity                         165
# Total Amount               3052.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105084 ||| 19-06-2017
# ------------------------------------
#
# Quantity                         119
# Total Amount               2142.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105249 ||| 30-06-2017
# ------------------------------------
#
# Quantity                         109
# Total Amount               3161.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105264 ||| 03-07-2017
# ------------------------------------
#
# Quantity                         149
# Total Amount               2384.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105297 ||| 04-07-2017
# ------------------------------------
#
# Quantity                         197
# Total Amount               3053.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105299 ||| 05-07-2017
# ------------------------------------
#
# Quantity                         129
# Total Amount               1483.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105300 ||| 05-07-2017
# ------------------------------------
#
# Quantity                          98
# Total Amount               1274.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105351 ||| 07-07-2017
# ------------------------------------
#
# Quantity                         139
# Total Amount               3892.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105377 ||| 11-07-2017
# ------------------------------------
#
# Quantity                         184
# Total Amount               3496.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105378 ||| 11-07-2017
# ------------------------------------
#
# Quantity                         119
# Total Amount               2380.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105412 ||| 13-07-2017
# ------------------------------------
#
# Quantity                          84
# Total Amount               1596.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105419 ||| 13-07-2017
# ------------------------------------
#
# Quantity                          55
# Total Amount                990.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105496 ||| 19-07-2017
# ------------------------------------
#
# Quantity                         164
# Total Amount               2788.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105518 ||| 20-07-2017
# ------------------------------------
#
# Quantity                         206
# Total Amount               4429.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105537 ||| 21-07-2017
# ------------------------------------
#
# Quantity                         177
# Total Amount               4071.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105549 ||| 24-07-2017
# ------------------------------------
#
# Quantity                         142
# Total Amount               2059.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105564 ||| 25-07-2017
# ------------------------------------
#
# Quantity                         103
# Total Amount               2163.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105570 ||| 25-07-2017
# ------------------------------------
#
# Quantity                         132
# Total Amount               2574.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105572 ||| 25-07-2017
# ------------------------------------
#
# Quantity                          90
# Total Amount               2070.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105572 ||| 25-07-2017
# ------------------------------------
#
# Quantity                         118
# Total Amount               2478.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105612 ||| 27-07-2017
# ------------------------------------
#
# Quantity                         225
# Total Amount               4275.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105657 ||| 31-07-2017
# ------------------------------------
#
# Quantity                         121
# Total Amount               2359.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105668 ||| 01-08-2017
# ------------------------------------
#
# Quantity                         199
# Total Amount               4875.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105720 ||| 04-08-2017
# ------------------------------------
#
# Quantity                         206
# Total Amount               2369.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105739 ||| 07-08-2017
# ------------------------------------
#
# Quantity                         109
# Total Amount               2398.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105768 ||| 08-08-2017
# ------------------------------------
#
# Quantity                         183
# Total Amount               4849.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105777 ||| 09-08-2017
# ------------------------------------
#
# Quantity                         213
# Total Amount               5112.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105831 ||| 14-08-2017
# ------------------------------------
#
# Quantity                         147
# Total Amount               2646.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105867 ||| 15-08-2017
# ------------------------------------
#
# Quantity                          70
# Total Amount               1855.00 €
#
#
#
# ************************************
#
#
# Receipt Number 105883 ||| 16-08-2017
# ------------------------------------
#
# Quantity                         171
# Total Amount               4873.50 €
#
#
#
# ************************************
#
#
# Receipt Number 105983 ||| 24-08-2017
# ------------------------------------
#
# Quantity                         124
# Total Amount               1426.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106021 ||| 28-08-2017
# ------------------------------------
#
# Quantity                         155
# Total Amount               3410.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106065 ||| 30-08-2017
# ------------------------------------
#
# Quantity                         161
# Total Amount               3944.50 €
#
#
#
# ************************************
#
#
# Receipt Number 106095 ||| 31-08-2017
# ------------------------------------
#
# Quantity                         173
# Total Amount               2854.50 €
#
#
#
# ************************************
#
#
# Receipt Number 106119 ||| 04-09-2017
# ------------------------------------
#
# Quantity                         162
# Total Amount               3888.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106150 ||| 05-09-2017
# ------------------------------------
#
# Quantity                         192
# Total Amount               3744.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106153 ||| 06-09-2017
# ------------------------------------
#
# Quantity                         212
# Total Amount               6678.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106174 ||| 07-09-2017
# ------------------------------------
#
# Quantity                         136
# Total Amount               2924.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106256 ||| 13-09-2017
# ------------------------------------
#
# Quantity                         174
# Total Amount               3741.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106316 ||| 18-09-2017
# ------------------------------------
#
# Quantity                         128
# Total Amount               2816.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106322 ||| 18-09-2017
# ------------------------------------
#
# Quantity                         122
# Total Amount               2135.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106330 ||| 19-09-2017
# ------------------------------------
#
# Quantity                         149
# Total Amount               3725.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106336 ||| 19-09-2017
# ------------------------------------
#
# Quantity                         181
# Total Amount               2805.50 €
#
#
#
# ************************************
#
#
# Receipt Number 106346 ||| 20-09-2017
# ------------------------------------
#
# Quantity                         136
# Total Amount               2244.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106370 ||| 21-09-2017
# ------------------------------------
#
# Quantity                         189
# Total Amount               4819.50 €
#
#
#
# ************************************
#
#
# Receipt Number 106376 ||| 21-09-2017
# ------------------------------------
#
# Quantity                         151
# Total Amount               4152.50 €
#
#
#
# ************************************
#
#
# Receipt Number 106439 ||| 27-09-2017
# ------------------------------------
#
# Quantity                         172
# Total Amount               3096.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106463 ||| 28-09-2017
# ------------------------------------
#
# Quantity                         172
# Total Amount               4214.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106494 ||| 29-09-2017
# ------------------------------------
#
# Quantity                         155
# Total Amount               2015.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106542 ||| 04-10-2017
# ------------------------------------
#
# Quantity                         113
# Total Amount               2316.50 €
#
#
#
# ************************************
#
#
# Receipt Number 106598 ||| 09-10-2017
# ------------------------------------
#
# Quantity                         121
# Total Amount               1936.00 €
#
#
#
# ************************************
#
#
# Receipt Number 106648 ||| 12-10-2017
# ------------------------------------
#
# Quantity                         179
# Total Amount               4743.50 €
#
#
#
# ************************************
#
#
# Receipt Number 106839 ||| 26-10-2017
# ------------------------------------
#
# Quantity                         108
# Total Amount               2484.00 €
#
#
#
# ************************************
#
#
# Receipt Number 107482 ||| 12-12-2017
# ------------------------------------
#
# Quantity                         193
# Total Amount               2605.50 €
#
#
#
# ************************************
#
#
# Receipt Number 107538 ||| 15-12-2017
# ------------------------------------
#
# Quantity                         148
# Total Amount               1850.00 €

# %%
for receipt in receipts_list:
    date_pattern = r"\d{2}-\d{2}-\d{4}"
    date = re.findall(date_pattern, receipt)[0]

# %%
for receipt in receipts_list:
    date_pattern = r"\d{2}-\d{2}-\d{4}"
    date = re.findall(date_pattern, receipt)[0]
    amount_pattern = r"Total Amount +(\d+\.\d{2}) €"
    amount = re.findall(amount_pattern, receipt)[0]

# %%
for receipt in receipts_list:
    date_pattern = r"\d{2}-\d{2}-\d{4}"
    date = re.findall(date_pattern, receipt)[0]
    amount_pattern = r"Total Amount +(\d+\.\d{2}) €"
    amount = re.findall(amount_pattern, receipt)[0]
    quantity_pattern = r"Quantity +(\d+)"
    quantity = re.findall(quantity_pattern, receipt)[0]

# %%
 print(f"date: {date}, amount: {amount}, quantity: {quantity}")
# Out:
# date: 15-12-2017, amount: 1850.00, quantity: 148

# %%
for receipt in receipts_list:
    date_pattern = r"\d{2}-\d{2}-\d{4}"
    date = re.findall(date_pattern, receipt)[0]
    amount_pattern = r"Total Amount +(\d+\.\d{2}) €"
    amount = re.findall(amount_pattern, receipt)[0]
    quantity_pattern = r"Quantity +(\d+)"
    quantity = re.findall(quantity_pattern, receipt)[0]
    receipts_dict["date"].append(date)
    receipts_dict["amount"].append(amount)
    receipts_dict["quantity"].append(quantity)

# %%
receipts_df = pd.DataFrame.from_dict(receipts_dict)
receipts_df.head()
# Out:
#          date quantity   amount
# 0  02-01-2017      163  3097.00
# 1  05-01-2017      110   935.00
# 2  23-01-2017      156  2808.00
# 3  31-01-2017      182  4368.00
# 4  06-02-2017       97  1988.50

# %%
from nbresult import ChallengeResult

result = ChallengeResult('receipts',
    raw=receipts_list,
    receipts=receipts_dict,
    df_size=receipts_df.shape,
    receipt=receipts_df.iloc[-1, :]
)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /Users/francoisgirard/.pyenv/versions/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/francoisgirard/code/francoisgirard51/02-Data-Toolkit/02-Data-Sourcing/data-text-extraction-with-regex/tests
# plugins: asyncio-0.19.0, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 4 items
#
# test_receipts.py::TestReceipts::test_receipt PASSED                      [ 25%]
# test_receipts.py::TestReceipts::test_receipts_df_size PASSED             [ 50%]
# test_receipts.py::TestReceipts::test_receipts_dict PASSED                [ 75%]
# test_receipts.py::TestReceipts::test_receipts_list PASSED                [100%]
#
# ============================== 4 passed in 0.75s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/receipts.pickle
#
# git commit -m 'Completed receipts step'
#
# git push origin master

# %% [markdown]
# # Part 3: Data Visualization

# %%
receipts_df['date'] = pd.to_datetime(receipts_df['date'], format="%d-%m-%Y")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [85], line 1
# ----> 1 receipts_df['date'] = pd.to_datetime(receipts_df['date'], format="%d-%m-%Y")
#
# NameError: name 'receipts_df' is not defined
